# %% [markdown]
# ## Get the Data
#
# Either use the provided .csv file or (optionally) get fresh (the freshest?) data from running an SQL query on StackExchange:
#
# Follow this link to run the query from [StackExchange](https://data.stackexchange.com/stackoverflow/query/675441/popular-programming-languages-per-over-time-eversql-com) to get your own .csv file
#
# <code>
# select dateadd(month, datediff(month, 0, q.CreationDate), 0) m, TagName, count(*)
# from PostTags pt
# join Posts q on q.Id=pt.PostId
# join Tags t on t.Id=pt.TagId
# where TagName in ('java','c','c++','python','c#','javascript','assembly','php','perl','ruby','visual basic','swift','r','object-c','scratch','go','swift','delphi')
# and q.CreationDate < dateadd(month, datediff(month, 0, getdate()), 0)
# group by dateadd(month, datediff(month, 0, q.CreationDate), 0), TagName
# order by dateadd(month, datediff(month, 0, q.CreationDate), 0)
# </code>

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# **Challenge**: Read the .csv file and store it in a Pandas dataframe

# %%
data = pd.read_csv("QueryResults.csv")

# %% [markdown]
# **Challenge**: Examine the first 5 rows and the last 5 rows of the of the dataframe

# %%
data.head()
# Out:
#                      m     TagName  Unnamed: 2
# 0  2008-07-01 00:00:00          c#           3
# 1  2008-08-01 00:00:00  javascript         163
# 2  2008-08-01 00:00:00        perl          28
# 3  2008-08-01 00:00:00          c#         504
# 4  2008-08-01 00:00:00      delphi          13

# %%
data.tail()
# Out:
#                      m     TagName  Unnamed: 2
# 0  2008-07-01 00:00:00          c#           3
# 1  2008-08-01 00:00:00  javascript         163
# 2  2008-08-01 00:00:00        perl          28
# 3  2008-08-01 00:00:00          c#         504
# 4  2008-08-01 00:00:00      delphi          13

# %% [markdown]
# **Challenge:** Check how many rows and how many columns there are.
# What are the dimensions of the dataframe?

# %%
data.shape
# Out:
# (2607, 3)

# %% [markdown]
# **Challenge**: Count the number of entries in each column of the dataframe

# %%
count = data["Unnamed: 2"].sum()

# %%
count
# Out:
# 12225013

# %% [markdown]
# **Challenge**: Calculate the total number of post per language.
# Which Programming language has had the highest total number of posts of all time?

# %%
dg = data.groupby("TagName").sum()

# %%
dg
# Out:
#                                                             m  Unnamed: 2
# TagName
# assembly    2008-08-01 00:00:002008-09-01 00:00:002008-10-...       44183
# c           2008-08-01 00:00:002008-09-01 00:00:002008-10-...      403716
# c#          2008-07-01 00:00:002008-08-01 00:00:002008-09-...     1614222
# c++         2008-08-01 00:00:002008-09-01 00:00:002008-10-...      806193
# delphi      2008-08-01 00:00:002008-09-01 00:00:002008-10-...       51826
# go          2009-11-01 00:00:002009-12-01 00:00:002010-01-...       72738
# java        2008-08-01 00:00:002008-09-01 00:00:002008-10-...     1916133
# javascript  2008-08-01 00:00:002008-09-01 00:00:002008-10-...     2527095
# perl        2008-08-01 00:00:002008-09-01 00:00:002008-10-...       68090
# php         2008-08-01 00:00:002008-09-01 00:00:002008-10-...     1463888
# python      2008-08-01 00:00:002008-09-01 00:00:002008-10-...     2189582
# r           2008-09-01 00:00:002008-11-01 00:00:002008-12-...      505145
# ruby        2008-08-01 00:00:002008-09-01 00:00:002008-10-...      229005
# swift       2009-01-01 00:00:002009-02-01 00:00:002009-03-...      333197

# %% [markdown]
# Some languages are older (e.g., C) and other languages are newer (e.g., Swift). The dataset starts in September 2008.
#
# **Challenge**: How many months of data exist per language? Which language had the fewest months with an entry?

# %%
dg = data.groupby("TagName").count()

# %%
dg
# Out:
#               m  Unnamed: 2
# TagName
# assembly    188         188
# c           188         188
# c#          189         189
# c++         188         188
# delphi      188         188
# go          173         173
# java        188         188
# javascript  188         188
# perl        188         188
# php         188         188
# python      188         188
# r           186         186
# ruby        188         188
# swift       179         179

# %% [markdown]
# ## Data Cleaning
#
# Let's fix the date format to make it more readable. We need to use Pandas to change format from a string of "2008-07-01 00:00:00" to a datetime object with the format of "2008-07-01"

# %%
data["m"] = pd.to_datetime(data["m"])

# %%
data["m"].head()
# Out:
# 0   2008-07-01
# 1   2008-08-01
# 2   2008-08-01
# 3   2008-08-01
# 4   2008-08-01
# Name: m, dtype: datetime64[ns]

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# **Challenge**: What are the dimensions of our new dataframe? How many rows and columns does it have? Print out the column names and print out the first 5 rows of the dataframe.

# %%
data.columns
# Out:
# Index(['m', 'TagName', 'Unnamed: 2'], dtype='object')

# %%
reshaped_df = data.pivot(index='m', columns='TagName', values='Unnamed: 2')

# %%
reshaped_df
# Out:
# TagName     assembly      c      c#     c++  delphi     go    java  \
# m
# 2008-07-01       NaN    NaN     3.0     NaN     NaN    NaN     NaN
# 2008-08-01       8.0   83.0   504.0   164.0    13.0    NaN   222.0
# 2008-09-01      28.0  320.0  1639.0   755.0   104.0    NaN  1129.0
# 2008-10-01      16.0  303.0  1987.0   807.0   112.0    NaN  1148.0
# 2008-11-01      16.0  258.0  1729.0   734.0   140.0    NaN   954.0
# ...              ...    ...     ...     ...     ...    ...     ...
# 2023-11-01     172.0  958.0  3105.0  1466.0   103.0  408.0  3273.0
# 2023-12-01     181.0  876.0  2645.0  1428.0    75.0  326.0  2536.0
# 2024-01-01     176.0  825.0  2685.0  1579.0    89.0  345.0  2864.0
# 2024-02-01     134.0  774.0  2708.0  1443.0   110.0  306.0  2796.0
# 2024-03-01     155.0  797.0  2884.0  1611.0   105.0  385.0  3332.0
#
# TagName     javascript   perl     php  python       r   ruby  swift
# m
# 2008-07-01         NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 2008-08-01       163.0   28.0   157.0   119.0     NaN   70.0    NaN
# 2008-09-01       634.0  130.0   474.0   537.0     6.0  286.0    NaN
# 2008-10-01       722.0  128.0   604.0   506.0     NaN  247.0    NaN
# 2008-11-01       580.0   97.0   497.0   448.0     1.0  157.0    NaN
# ...                ...    ...     ...     ...     ...    ...    ...
# 2023-11-01      5183.0   44.0  1397.0  8450.0  1991.0  153.0  864.0
# 2023-12-01      4762.0   53.0  1207.0  6993.0  1602.0  154.0  740.0
# 2024-01-01      5128.0   34.0  1400.0  7756.0  1807.0  163.0  867.0
# 2024-02-01      4769.0   36.0  1305.0  7836.0  1825.0  157.0  671.0
# 2024-03-01      5336.0   52.0  1590.0  8419.0  1790.0  147.0  814.0
#
# [189 rows x 14 columns]

# %% [markdown]
# **Challenge**: Count the number of entries per programming language. Why might the number of entries be different?

# %%
reshaped_df.head()
# Out:
# TagName              assembly      c      c#    c++  delphi  go    java  \
# m
# 2008-07-01 00:00:00       NaN    NaN     3.0    NaN     NaN NaN     NaN
# 2008-08-01 00:00:00       8.0   83.0   504.0  164.0    13.0 NaN   222.0
# 2008-09-01 00:00:00      28.0  320.0  1639.0  755.0   104.0 NaN  1129.0
# 2008-10-01 00:00:00      16.0  303.0  1987.0  807.0   112.0 NaN  1148.0
# 2008-11-01 00:00:00      16.0  258.0  1729.0  734.0   140.0 NaN   954.0
#
# TagName              javascript   perl    php  python    r   ruby  swift
# m
# 2008-07-01 00:00:00         NaN    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01 00:00:00       163.0   28.0  157.0   119.0  NaN   70.0    NaN
# 2008-09-01 00:00:00       634.0  130.0  474.0   537.0  6.0  286.0    NaN
# 2008-10-01 00:00:00       722.0  128.0  604.0   506.0  NaN  247.0    NaN
# 2008-11-01 00:00:00       580.0   97.0  497.0   448.0  1.0  157.0    NaN

# %%
reshaped_df.fillna(0, inplace=True)

# %%
reshaped_df.count()
# Out:
# TagName
# assembly      189
# c             189
# c#            189
# c++           189
# delphi        189
# go            189
# java          189
# javascript    189
# perl          189
# php           189
# python        189
# r             189
# ruby          189
# swift         189
# dtype: int64

# %% [markdown]
# ## Data Visualisaton with with Matplotlib

# %% [markdown]
# **Challenge**: Use the [matplotlib documentation](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) to plot a single programming language (e.g., java) on a chart.

# %%
plt.figure(figsize=(16,10)) 
plt.plot(reshaped_df.index, reshaped_df.java)
plt.plot(reshaped_df.index, reshaped_df.python)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0,35000)
# Out:
# (0.0, 35000.0)

# %%
plt.figure(figsize=(16,10)) 
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
for column in reshaped_df.columns:
    plt.plot(reshaped_df.index, reshaped_df[column], label=f"{column}")
plt.legend(loc="upper left")

# %% [markdown]
# **Challenge**: Show two line (e.g. for Java and Python) on the same chart.

# %% [markdown]
# # Smoothing out Time Series Data
#
# Time series data can be quite noisy, with a lot of up and down spikes. To better see a trend we can plot an average of, say 6 or 12 observations. This is called the rolling mean. We calculate the average in a window of time and move it forward by one overservation. Pandas has two handy methods already built in to work this out: [rolling()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html) and [mean()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.window.rolling.Rolling.mean.html).

# %%
roll_df = reshaped_df.rolling(window=6).mean()
 
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0, 35000)
 
# plot the roll_df instead
for column in roll_df.columns:
    plt.plot(roll_df.index, roll_df[column], 
             linewidth=3, label=roll_df[column].name)
 
plt.legend(fontsize=16)

# %%
plt.figure(figsize=(16,10)) 
plt.plot(reshaped_df.index, reshaped_df.javascript, label="js")
plt.plot(reshaped_df.index, reshaped_df.python, label="python")
plt.plot(reshaped_df.index, reshaped_df.java, label="java")
plt.plot(reshaped_df.index, reshaped_df["php"], label="php")
plt.legend(fontsize=16)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Posts', fontsize=14)
plt.ylim(0,35000)
# Out:
# (0.0, 35000.0)
